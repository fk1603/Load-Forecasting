# %% [markdown]
# # Temporal Fusion Transformer (TFT)
#
# This notebook covers the impementation of a TFT model for load forecasting purposes.
#
# The model is implemented using the Darts python package
#
# Please pip install the requirements.txt file before running
#
# Authors: Ali Kamran, (Andreas Liiv, Florian Kühn)

# %%
# %pip install -r TFT_requirements.txt
# Out:
# Requirement already satisfied: adagio==0.2.6 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 1)) (0.2.6)
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiohttp==3.11.18 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 3)) (3.11.18)
# Requirement already satisfied: aiosignal==1.3.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: alembic==1.16.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 5)) (1.16.1)
# Requirement already satisfied: anyio==4.9.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: appdirs==1.4.4 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: argon2-cffi==23.1.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 8)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: asttokens==3.0.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: async-lru==2.0.5 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 12)) (2.0.5)
# Requirement already satisfied: attrs==25.3.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 13)) (25.3.0)
# Requirement already satisfied: autopep8==2.3.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 14)) (2.3.2)
# Requirement already satisfied: babel==2.17.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 15)) (2.17.0)
# Requirement already satisfied: beautifulsoup4==4.13.4 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 16)) (4.13.4)
# Requirement already satisfied: bleach==6.2.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 17)) (6.2.0)
# Requirement already satisfied: catboost==1.2.8 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 18)) (1.2.8)
# Requirement already satisfied: certifi==2025.4.26 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 19)) (2025.4.26)
# Requirement already satisfied: cffi==1.17.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 20)) (1.17.1)
# Requirement already satisfied: charset-normalizer==3.4.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 21)) (3.4.2)
# Requirement already satisfied: cloudpickle==3.1.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 22)) (3.1.1)
# Requirement already satisfied: cmdstanpy==1.2.5 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 23)) (1.2.5)
# Requirement already satisfied: colorama==0.4.6 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 24)) (0.4.6)
# Requirement already satisfied: colorlog==6.9.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 25)) (6.9.0)
# Requirement already satisfied: comm==0.2.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 26)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 27)) (1.3.2)
# Requirement already satisfied: coreforecast==0.0.16 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 28)) (0.0.16)
# Requirement already satisfied: cycler==0.12.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 29)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.14 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 30)) (1.8.14)
# Requirement already satisfied: decorator==5.2.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 31)) (5.2.1)
# Requirement already satisfied: defusedxml==0.7.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 32)) (0.7.1)
# Requirement already satisfied: executing==2.2.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 33)) (2.2.0)
# Requirement already satisfied: fastjsonschema==2.21.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 34)) (2.21.1)
# Requirement already satisfied: filelock==3.18.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 35)) (3.18.0)
# Requirement already satisfied: fonttools==4.58.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 36)) (4.58.0)
# Requirement already satisfied: fqdn==1.5.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 37)) (1.5.1)
# Requirement already satisfied: frozenlist==1.6.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 38)) (1.6.0)
# Requirement already satisfied: fs==2.4.16 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 39)) (2.4.16)
# Requirement already satisfied: fsspec==2025.5.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 40)) (2025.5.0)
# Requirement already satisfied: fugue==0.9.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 41)) (0.9.1)
# Requirement already satisfied: graphviz==0.20.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 42)) (0.20.3)
# Requirement already satisfied: greenlet==3.2.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 43)) (3.2.2)
# Requirement already satisfied: h11==0.16.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 44)) (0.16.0)
# Requirement already satisfied: holidays==0.73 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 45)) (0.73)
# Requirement already satisfied: httpcore==1.0.9 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 46)) (1.0.9)
# Requirement already satisfied: httpx==0.28.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 47)) (0.28.1)
# Requirement already satisfied: idna==3.10 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 48)) (3.10)
# Requirement already satisfied: importlib_resources==6.5.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 49)) (6.5.2)
# Requirement already satisfied: ipykernel==6.29.5 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 50)) (6.29.5)
# Requirement already satisfied: ipython==9.2.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 51)) (9.2.0)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 52)) (1.1.1)
# Requirement already satisfied: ipywidgets==8.1.7 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 53)) (8.1.7)
# Requirement already satisfied: isoduration==20.11.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 54)) (20.11.0)
# Requirement already satisfied: jedi==0.19.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 55)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 56)) (3.1.6)
# Requirement already satisfied: joblib==1.5.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 57)) (1.5.0)
# Requirement already satisfied: json5==0.12.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 58)) (0.12.0)
# Requirement already satisfied: jsonpointer==3.0.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 59)) (3.0.0)
# Requirement already satisfied: jsonschema==4.23.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 60)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2025.4.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 61)) (2025.4.1)
# Requirement already satisfied: jupyter==1.1.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 62)) (1.1.1)
# Requirement already satisfied: jupyter-console==6.6.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 63)) (6.6.3)
# Requirement already satisfied: jupyter-events==0.12.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 64)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 65)) (2.2.5)
# Requirement already satisfied: jupyter_client==8.6.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 66)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 67)) (5.7.2)
# Requirement already satisfied: jupyter_server==2.16.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 68)) (2.16.0)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 69)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.4.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 70)) (4.4.2)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 71)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.27.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 72)) (2.27.3)
# Requirement already satisfied: jupyterlab_widgets==3.0.15 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 73)) (3.0.15)
# Requirement already satisfied: jupytext==1.17.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 74)) (1.17.1)
# Requirement already satisfied: kiwisolver==1.4.8 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 75)) (1.4.8)
# Requirement already satisfied: lightgbm==4.6.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 76)) (4.6.0)
# Requirement already satisfied: lightning-utilities==0.14.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 77)) (0.14.3)
# Requirement already satisfied: llvmlite==0.44.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 78)) (0.44.0)
# Requirement already satisfied: Mako==1.3.10 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 79)) (1.3.10)
# Requirement already satisfied: markdown-it-py==3.0.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 80)) (3.0.0)
# Requirement already satisfied: MarkupSafe==3.0.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 81)) (3.0.2)
# Requirement already satisfied: matplotlib==3.10.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 82)) (3.10.3)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 83)) (0.1.7)
# Requirement already satisfied: mdit-py-plugins==0.4.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 84)) (0.4.2)
# Requirement already satisfied: mdurl==0.1.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 85)) (0.1.2)
# Requirement already satisfied: mistune==3.1.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 86)) (3.1.3)
# Requirement already satisfied: mpmath==1.3.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 87)) (1.3.0)
# Requirement already satisfied: multidict==6.4.4 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 88)) (6.4.4)
# Requirement already satisfied: narwhals==1.40.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 89)) (1.40.0)
# Requirement already satisfied: nbclient==0.10.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 90)) (0.10.2)
# Requirement already satisfied: nbconvert==7.16.6 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 91)) (7.16.6)
# Requirement already satisfied: nbformat==5.10.4 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 92)) (5.10.4)
# Requirement already satisfied: nbstripout==0.8.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 93)) (0.8.1)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 94)) (1.6.0)
# Requirement already satisfied: networkx==3.4.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 95)) (3.4.2)
# Requirement already satisfied: nfoursid==1.0.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 96)) (1.0.1)
# Requirement already satisfied: notebook==7.4.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 97)) (7.4.2)
# Requirement already satisfied: notebook_shim==0.2.4 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 98)) (0.2.4)
# Requirement already satisfied: numba==0.61.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 99)) (0.61.2)
# Requirement already satisfied: numpy==2.2.6 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 100)) (2.2.6)
# Requirement already satisfied: optuna==4.3.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 101)) (4.3.0)
# Requirement already satisfied: overrides==7.7.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 102)) (7.7.0)
# Requirement already satisfied: packaging==25.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 103)) (25.0)
# Requirement already satisfied: pandas==2.2.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 104)) (2.2.3)
# Requirement already satisfied: pandocfilters==1.5.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 105)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 106)) (0.8.4)
# Requirement already satisfied: patsy==1.0.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 107)) (1.0.1)
# Requirement already satisfied: pillow==11.2.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 108)) (11.2.1)
# Requirement already satisfied: platformdirs==4.3.8 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 109)) (4.3.8)
# Requirement already satisfied: plotly==6.1.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 110)) (6.1.1)
# Requirement already satisfied: prometheus_client==0.22.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 111)) (0.22.0)
# Requirement already satisfied: prompt_toolkit==3.0.51 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 112)) (3.0.51)
# Requirement already satisfied: propcache==0.3.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 113)) (0.3.1)
# Requirement already satisfied: prophet==1.1.6 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 114)) (1.1.6)
# Requirement already satisfied: protobuf==6.31.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 115)) (6.31.0)
# Requirement already satisfied: psutil==7.0.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 116)) (7.0.0)
# Requirement already satisfied: pure_eval==0.2.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 117)) (0.2.3)
# Requirement already satisfied: pyarrow==20.0.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 118)) (20.0.0)
# Requirement already satisfied: pycodestyle==2.13.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 119)) (2.13.0)
# Requirement already satisfied: pycparser==2.22 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 120)) (2.22)
# Requirement already satisfied: Pygments==2.19.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 121)) (2.19.1)
# Requirement already satisfied: pyod==2.0.5 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 122)) (2.0.5)
# Requirement already satisfied: pyparsing==3.2.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 123)) (3.2.3)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 124)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==3.3.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 125)) (3.3.0)
# Requirement already satisfied: pytorch-lightning==2.5.1.post0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 126)) (2.5.1.post0)
# Requirement already satisfied: pytz==2025.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 127)) (2025.2)
# Requirement already satisfied: pywin32==310 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 128)) (310)
# Requirement already satisfied: pywinpty==2.0.15 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 129)) (2.0.15)
# Requirement already satisfied: PyYAML==6.0.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 130)) (6.0.2)
# Requirement already satisfied: pyzmq==26.4.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 131)) (26.4.0)
# Requirement already satisfied: referencing==0.36.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 132)) (0.36.2)
# Requirement already satisfied: requests==2.32.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 133)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 134)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 135)) (0.1.1)
# Requirement already satisfied: rpds-py==0.25.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 136)) (0.25.1)
# Requirement already satisfied: scikit-learn==1.6.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 137)) (1.6.1)
# Requirement already satisfied: scipy==1.15.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 138)) (1.15.3)
# Requirement already satisfied: seaborn==0.13.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 139)) (0.13.2)
# Requirement already satisfied: Send2Trash==1.8.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 140)) (1.8.3)
# Requirement already satisfied: setuptools==80.8.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 141)) (80.8.0)
# Requirement already satisfied: shap==0.47.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 142)) (0.47.2)
# Requirement already satisfied: six==1.17.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 143)) (1.17.0)
# Requirement already satisfied: slicer==0.0.8 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 144)) (0.0.8)
# Requirement already satisfied: sniffio==1.3.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 145)) (1.3.1)
# Requirement already satisfied: soupsieve==2.7 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 146)) (2.7)
# Requirement already satisfied: SQLAlchemy==2.0.41 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 147)) (2.0.41)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 148)) (0.6.3)
# Requirement already satisfied: stanio==0.5.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 149)) (0.5.1)
# Requirement already satisfied: statsforecast==2.0.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 150)) (2.0.1)
# Requirement already satisfied: statsmodels==0.14.4 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 151)) (0.14.4)
# Requirement already satisfied: sympy==1.14.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 152)) (1.14.0)
# Requirement already satisfied: tensorboardX==2.6.2.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 153)) (2.6.2.2)
# Requirement already satisfied: terminado==0.18.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 154)) (0.18.1)
# Requirement already satisfied: threadpoolctl==3.6.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 155)) (3.6.0)
# Requirement already satisfied: tinycss2==1.4.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 156)) (1.4.0)
# Requirement already satisfied: torch==2.7.0+cu118 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 157)) (2.7.0+cu118)
# Requirement already satisfied: torchaudio==2.7.0+cu118 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 158)) (2.7.0+cu118)
# Requirement already satisfied: torchmetrics==1.7.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 159)) (1.7.1)
# Requirement already satisfied: torchvision==0.22.0+cu118 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 160)) (0.22.0+cu118)
# Requirement already satisfied: tornado==6.5.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 161)) (6.5.1)
# Requirement already satisfied: tqdm==4.67.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 162)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 163)) (5.14.3)
# Requirement already satisfied: triad==0.9.8 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 164)) (0.9.8)
# Requirement already satisfied: types-python-dateutil==2.9.0.20250516 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 165)) (2.9.0.20250516)
# Requirement already satisfied: typing_extensions==4.13.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 166)) (4.13.2)
# Requirement already satisfied: tzdata==2025.2 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 167)) (2025.2)
# Requirement already satisfied: u8darts==0.35.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 168)) (0.35.0)
# Requirement already satisfied: uri-template==1.3.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 169)) (1.3.0)
# Requirement already satisfied: urllib3==2.4.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 170)) (2.4.0)
# Requirement already satisfied: utilsforecast==0.2.12 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 171)) (0.2.12)
# Requirement already satisfied: wcwidth==0.2.13 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 172)) (0.2.13)
# Requirement already satisfied: webcolors==24.11.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 173)) (24.11.1)
# Requirement already satisfied: webencodings==0.5.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 174)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 175)) (1.8.0)
# Requirement already satisfied: widgetsnbextension==4.0.14 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 176)) (4.0.14)
# Requirement already satisfied: xarray==2025.4.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 177)) (2025.4.0)
# Requirement already satisfied: xgboost==3.0.1 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 178)) (3.0.1)
# Requirement already satisfied: yarl==1.20.0 in c:\users\ali kamran\pycharmprojects\load-forecasting\venv\lib\site-packages (from -r TFT_requirements.txt (line 179)) (1.20.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import required modules
from darts.explainability.tft_explainer import TFTExplainer
import seaborn as sns
import matplotlib.pyplot as plt
from pytorch_lightning.callbacks import Callback
from optuna.exceptions import TrialPruned
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
import warnings  # Suppress warnings for cleaner output
import os  # Operating system interface
import optuna  # Hyperparameter optimization
import numpy as np  # Numerical operations
import pandas as pd  # Data manipulation
import torch  # PyTorch for deep learning
from darts.utils.likelihood_models.base import LikelihoodType  # Darts likelihood types
from darts.metrics import mape, rmse, mse, mae, r2_score, smape  # Darts metrics
from darts import TimeSeries  # Darts TimeSeries object
from darts.dataprocessing.transformers import Scaler  # Data scaling
from darts.metrics import mape  # Mean Absolute Percentage Error
import holidays  # Holiday calculations
import torchmetrics  # PyTorch metrics
from torchmetrics.collections import MetricCollection  # Metric collection
from darts.models import TFTModel  # Temporal Fusion Transformer model
# Quantile regression for probabilistic forecasting
from darts.utils.likelihood_models import QuantileRegression
import torch.optim as optim  # PyTorch optimizers

# Set matrix multiplication precision
torch.set_float32_matmul_precision('medium')
device0 = torch.device("cuda" if torch.cuda.is_available()
                       else "cpu")  # Set device
# warnings.filterwarnings("ignore")  # Ignore warnings
print(torch.cuda.is_available())
# Out:
# True

# %%
def read_load_data():
    '''
    Reads load data from file 'processed_loadUTC_data.csv'.
    Renames columns for better handling in future code.

    Returns: DataFrame containing load data
    '''

    base_dir = os.getcwd()
    load_file_path = os.path.join(base_dir, 'processed_loadUTC_data.csv')
    load_data = pd.read_csv(load_file_path)
    load_data.rename(columns={
        "Actual Total Load [MW] - BZN|SE4": "Actual Load",
        "Time (UTC)": "Time"
    }, inplace=True)
    load_data['Time'] = pd.to_datetime(
        load_data['Time'].str.split(' - ').str[0], format='%d.%m.%Y %H:%M')
    load_data.set_index('Time', inplace=True)
    load_data.drop(
        'Day-ahead Total Load Forecast [MW] - BZN|SE4', axis=1, inplace=True)
    return load_data


data = read_load_data()

# %%
def import_weather_data(df, solar_power=False):
    '''
    The weighted averages of weather data (incl. temperature, humidity and solar irradiation) is read and added to the main dataframe.
    If "solar_power" is given as 'True', solar irradiation data is replaced by an estimate of total solar power generation.

    Parameters:
        df: pandas DataFrame
        solar_power: boolean for converting solar irradiation to solar power if 'True'

    Returns: input DataFrame appended with weather data
    '''

    base_dir = os.getcwd()
    temperature_file_path = os.path.join(base_dir, 'weighted_avg_temp.csv')
    humidity_file_path = os.path.join(base_dir, 'weighted_avg_humidity.csv')
    solar_file_path = os.path.join(base_dir, 'weighted_avg_solar.csv')
    avg_temperature_data = pd.read_csv(temperature_file_path)
    avg_humidity_data = pd.read_csv(humidity_file_path)
    avg_solar_data = pd.read_csv(solar_file_path)
    df['Temperature'] = avg_temperature_data['weighted_avg'].values
    df['Humidity'] = avg_humidity_data['weighted_avg'].values
    df['Solar_Irrad'] = avg_solar_data['weighted_avg'].values

    if solar_power:
        tot_installed_capacity = np.array([
            2.52, 5.04, 7.56, 10.08, 12.6, 18.6, 29.2, 41.53, 69.55, 85
        ]) * 1e6
        installed_capacity_house = 10 * 1e3
        n_installations = tot_installed_capacity / installed_capacity_house
        panel_per_house = 24
        area_per_panel = 2

        years = np.arange(2015, 2025)
        total_area_panels = n_installations * panel_per_house * area_per_panel
        area_by_year = dict(zip(years, total_area_panels))

        panel_efficiency = 0.2
        df['year'] = df.index.year
        df['Solar'] = df['Solar_Irrad'] * \
            df['year'].map(area_by_year) * panel_efficiency
        df.drop(columns='year', inplace=True)
    else:
        df['Solar'] = df['Solar_Irrad']
    df.drop(columns='Solar_Irrad', inplace=True)
    return df


data = import_weather_data(data, solar_power=True)

# %%
def import_swedish_holidays(df):
    '''
    Imports Swedish holidays into column 'is_holiday' of input DataFrame

    Parameters:
        df: pandas Dataframe

    Returns: DataFrame appended with Swedish holidays
    '''
    years = np.arange(2015, 2025)
    raw_holidays = []
    for date, name in sorted(holidays.Sweden(years=years).items()):
        if name != "Söndag":
            raw_holidays.append(date)
        raw_holidays.append(date)
    holiday_dates = set(raw_holidays)
    df['is_holiday'] = pd.Series(df.index.date).isin(
        holiday_dates).astype(int).values
    return df


data = import_swedish_holidays(data)

# %%
def create_date_features(df):
    '''
    Creates date features marking the hour of the day

    Parameters:
        df: pandas DataFrame

    Returns: DataFrame appended with hour
    '''
    df['hour'] = df.index.hour
    return df


data = create_date_features(data)

# %%
def add_noise_to_covariates(df, noise_level=0.05):
    """
    Adds Gaussian noise to weather-related covariates ('Temperature', 'Humidity', 'Solar').

    The function adds random noise with a standard deviation proportional to the value
    (for 'Solar') or to the column's standard deviation (for 'Temperature' and 'Humidity').
    This is useful for simulating measurement uncertainty or for data augmentation.

    Parameters
    ----------
    df : pandas.DataFrame
        Input DataFrame containing weather covariates.
    noise_level : float, optional
        Standard deviation of the Gaussian noise as a fraction of the value (default is 0.05).

    Returns
    -------
    pandas.DataFrame
        DataFrame with noisy weather covariates.
    """
    np.random.seed(42)  # Set random seed for reproducibility
    stochastic_cols = ["Temperature", "Humidity", "Solar"]
    df_noisy = df.copy()
    for col in stochastic_cols:
        if col in df_noisy.columns:
            if col == "Solar":
                base = df_noisy[col].values
                noise = np.random.normal(0, noise_level * base)
                df_noisy[col] += noise
                df_noisy[col] = df_noisy[col].clip(lower=0)
            else:
                std = df_noisy[col].std()
                noise = np.random.normal(
                    0, noise_level * std, size=len(df_noisy))
                df_noisy[col] += noise
    return df_noisy


# Retain the original data without noise
clean_future_data = data.copy()
future_data = add_noise_to_covariates(data)

# %%
def create_lag_features(df, load="Actual Load", nan=False):
    '''
    Creates lagged covariate and load features. Can fill target value (load) lags with NaNs if nan is 'True'.

    df: pandas DataFrame
    nan: fills all load lags with NaNs if 'True'
    '''

    df = df.copy()
    for lag in [1, 2, 3, 6, 12, 24]:
        df[f'lag_temp_{lag}'] = df["Temperature"].shift(lag)
        df[f'lag_humid_{lag}'] = df["Humidity"].shift(lag)
        df[f'lag_solar_{lag}'] = df["Solar"].shift(lag)
        if lag <= 3:
            df[f'lag_hour_{lag}'] = df["hour"].shift(lag)
        if nan:
            df[f'lag_{lag}'] = np.nan
        else:
            df[f'lag_{lag}'] = df[load].shift(lag)
    for day in range(2, 8):
        lag = day * 24
        if nan:
            df[f'lag_{lag}'] = np.nan
        else:
            df[f'lag_{lag}'] = df[load].shift(lag)
    return df


data = create_lag_features(data)
data = data.dropna()  # first week in 2015 dropped to enable lag features
print(data.columns.tolist())
# droping the lagged features not used in the model
data.drop(
    columns=[
        'lag_1',
        'lag_2',
        'lag_3',
        'lag_6',
        'lag_12',
        'lag_hour_1',
        'lag_hour_2',
        'lag_hour_1',
        'lag_hour_3',
    ],
    inplace=True)
# future_data = create_lag_features(future_data, nan=True)
future_data = future_data[future_data.index >= data.index.min()]
# Out:
# ['Actual Load', 'Temperature', 'Humidity', 'Solar', 'is_holiday', 'hour', 'lag_temp_1', 'lag_humid_1', 'lag_solar_1', 'lag_hour_1', 'lag_1', 'lag_temp_2', 'lag_humid_2', 'lag_solar_2', 'lag_hour_2', 'lag_2', 'lag_temp_3', 'lag_humid_3', 'lag_solar_3', 'lag_hour_3', 'lag_3', 'lag_temp_6', 'lag_humid_6', 'lag_solar_6', 'lag_6', 'lag_temp_12', 'lag_humid_12', 'lag_solar_12', 'lag_12', 'lag_temp_24', 'lag_humid_24', 'lag_solar_24', 'lag_24', 'lag_48', 'lag_72', 'lag_96', 'lag_120', 'lag_144', 'lag_168']

# %%
# drop all the data before 2022
data = data[data.index >= "2022-01-01"]

future_data = future_data[future_data.index >= "2022-01-01"]
clean_future_data = clean_future_data[clean_future_data.index >= "2022-01-01"]
# print(future_data.index)  # Should be DatetimeIndex

series = TimeSeries.from_dataframe(data, value_cols="Actual Load")
# print(series.columns.tolist())   # Lists all column names

# %%
# Split dates for training and validation sets
training_cutoff = pd.Timestamp("2023-12-31 23:00:00")
train_cov_cutoff = pd.Timestamp("2024-01-01 00:00:00")
validating_cutoff = pd.Timestamp("2024-06-30 23:00:00")

# %%
# Split after training_cutoff
train, rest = series.split_after(training_cutoff)

# Split the remaining data after validating_cutoff
val, test = rest.split_after(validating_cutoff)
print('Train Series:', train.start_time(), train.end_time())
print('Val Series:', val.start_time(), val.end_time())
print('Test Series:', test.start_time(), test.end_time())

# Normalize the time series (scaling)
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
val_transformed = transformer.transform(val)
series_transformed = transformer.transform(series)
test_transformed = transformer.transform(test)
# Out:
# Train Series: 2022-01-01 00:00:00 2023-12-31 23:00:00
# Val Series: 2024-01-01 00:00:00 2024-06-30 23:00:00
# Test Series: 2024-07-01 00:00:00 2024-12-31 23:00:00

# %%
# Select all columns except 'Actual Load'
value_cols = [col for col in data.columns if col != "Actual Load"]

# Create the TimeSeries (assuming index is datetime or time_col is defined)
past_covariates = TimeSeries.from_dataframe(data, value_cols=value_cols)
# Normalize historical covariates
scaler_covs = Scaler()
scaler_covs.fit(past_covariates[:training_cutoff])
past_covariates_transformed = scaler_covs.transform(past_covariates)
# Use same cutoff points for consistency
train_past_covs, rest_past_covs = past_covariates_transformed.split_after(
    training_cutoff)
val_past_covs, test_past_covs = rest_past_covs.split_after(validating_cutoff)
last24_ = train_past_covs[-24:]
val_past_covs = last24_.append(val_past_covs)

# %%
# Apply the same approach for future covariates:
# Right now we are using the same data as past covariates

# Drop "Actual Load" from value columns
value_cols = [col for col in future_data.columns if col != "Actual Load"]

# Create the TimeSeries
future_covariates = TimeSeries.from_dataframe(
    future_data, value_cols=value_cols)
clean_future_cov = TimeSeries.from_dataframe(
    clean_future_data, value_cols=value_cols)
# Clean future covariates for training as its not intended the model to
# learn the noise pattern otherwise it performs better
clean_train_future_covs, rest_future_covs = clean_future_cov.split_after(
    training_cutoff)
noisy_data, rest_data = future_covariates.split_after(training_cutoff)
print(clean_train_future_covs.end_time())
print(rest_data.start_time())
future_covariates = clean_train_future_covs.append(rest_data)

# Apply the same approach for future covariates:
scaler_covs_future = Scaler()
# Fit on training data
scaler_covs_future.fit(future_covariates[:training_cutoff])

# Transform all future covariates
future_covariates_transformed = scaler_covs_future.transform(future_covariates)

# Split transformed future covariates into training, validation, and test sets
train_future_covs, rest_future_covs = future_covariates_transformed.split_after(
    training_cutoff)
val_future_covs, test_future_covs = rest_future_covs.split_after(
    validating_cutoff)

last24_ = train_future_covs[-24:]

val_future_covs = last24_.append(val_future_covs)
print(val_future_covs.start_time(), val_future_covs.end_time())

# add the first 24 hours of val future covariates to the end of the train
# future covariates
next48 = val_future_covs[:48]
next24 = next48[-24:]
train_future_covs = train_future_covs.append(next24)
print(train_future_covs.start_time(), train_future_covs.end_time())
# Out:
# 2023-12-31 23:00:00
# 2024-01-01 00:00:00
# 2023-12-31 00:00:00 2024-06-30 23:00:00
# 2022-01-01 00:00:00 2024-01-01 23:00:00

# %%
# Define quantiles for QuantileRegression
quantiles = [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4,
             0.5, 0.6, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.99,]

# %%
def encode_year(index):
    """
    Encodes the year from a pandas DatetimeIndex as a pandas Series.

    Parameters
    ----------
    index : pandas.DatetimeIndex
        Datetime index from which to extract the year.

    Returns
    -------
    pandas.Series
        Series containing the year for each entry in the index.
    """
    return pd.Series(index.year, index=index)

# %%
class CustomPyTorchLightningPruningCallback(Callback):
    """
    Optuna pruning callback for PyTorch Lightning.

    This callback reports the validation loss to Optuna after each validation epoch.
    If Optuna decides the trial should be pruned (i.e., stopped early), it raises
    an exception to halt training.

    Parameters
    ----------
    trial : optuna.trial.Trial
        The Optuna trial object.
    monitor : str, optional
        The metric name to monitor for pruning (default is "val_loss").
    """

    def __init__(self, trial, monitor="val_loss"):
        self._trial = trial
        self._monitor = monitor

    def on_validation_end(self, trainer, pl_module):
        # Get the monitored metric from the trainer's callback metrics
        logs = trainer.callback_metrics
        current_score = logs.get(self._monitor)
        if current_score is None:
            return  # If the metric is not available, do nothing
        # Report the current score to Optuna
        self._trial.report(current_score, step=trainer.global_step)
        # If Optuna decides to prune, raise the exception to stop training
        if self._trial.should_prune():
            message = f"Trial was pruned at step {trainer.global_step}."
            raise optuna.TrialPruned(message)

# %%
# Check if CUDA-enabled GPU is available
if torch.cuda.is_available():
    print("CUDA-enabled GPU detected. Using GPU.")
    accelerator = "gpu"
    # Use the first GPU device (index 0)
    devices = [0]
else:
    print("No CUDA-enabled GPU detected. Using CPU.")
    accelerator = "cpu"
    # Use 1 device for CPU training (standard for PyTorch Lightning CPU)
    devices = 1
# Out:
# CUDA-enabled GPU detected. Using GPU.

# %%
def objective(trial):
    """
    Optuna objective function for hyperparameter optimization of the TFTModel.

    This function samples hyperparameters, initializes the TFTModel with those parameters,
    trains the model, and returns the MAPE score on the validation set for Optuna to minimize.

    Parameters
    ----------
    trial : optuna.trial.Trial
        An Optuna trial object for suggesting hyperparameters.

    Returns
    -------
    float
        The MAPE score on the validation set (to be minimized).
    """
    # Set up Optuna pruning and early stopping callbacks

    optuna_callback = CustomPyTorchLightningPruningCallback(
        trial, monitor="val_loss")
    early_stopper = EarlyStopping(
        monitor="val_loss",  # Using train_loss instead of val_loss might not be a good idea
        min_delta=0.005,
        patience=3,
        verbose=True
    )
    # Sample hyperparameters
    hidden_size = trial.suggest_categorical("hidden_size", [12, 24, 32])
    lstm_layers = trial.suggest_int("lstm_layers", 1, 4)
    dropout = trial.suggest_float("dropout", 0.1, 0.5)
    learning_rate = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
    input_chunk_length = trial.suggest_categorical(
        "input_chunk_length", [12, 24, 48])
    batch_size = 256

    # Initialize the TFT model with sampled hyperparameters

    model = TFTModel(
        model_name=f"TFT_trial_{trial.number}",
        input_chunk_length=input_chunk_length,
        output_chunk_length=24,
        hidden_size=hidden_size,
        lstm_layers=lstm_layers,
        dropout=dropout,
        batch_size=256,
        optimizer_kwargs={"lr": learning_rate},
        n_epochs=20,  # Keep it low for faster tuning
        likelihood=QuantileRegression(quantiles=quantiles),
        random_state=42,
        add_encoders={
            'cyclic': {'future': ['month', 'day', 'weekday', 'dayofweek', 'hour', 'dayofyear', 'weekofyear'],
                       'past': ['month', 'day', 'weekday', 'dayofweek', 'hour', 'dayofyear', 'weekofyear']},
            'datetime_attribute': {'future': ['hour', 'dayofweek']},
            'position': {'past': ['relative'], 'future': ['relative']},
            'custom': {'past': [encode_year]},
            'transformer': Scaler(),
            'tz': 'UTC'},

        pl_trainer_kwargs={
            "accelerator": accelerator,
            "devices": devices,
            "enable_progress_bar": True,
            "callbacks": [early_stopper, optuna_callback],
        },
        force_reset=True
    )
    # Train the model

    model.fit(
        train_transformed[24:],
        past_covariates=train_past_covs,
        future_covariates=train_future_covs,
        val_series=val_transformed,
        val_past_covariates=val_past_covs,
        val_future_covariates=val_future_covs,
        verbose=True,
    )

    # Forecast and compute MAPE on the validation set
    pred = model.predict(
        n=len(val_transformed),
        series=train_transformed,
        past_covariates=val_past_covs,
        future_covariates=val_future_covs,
        num_samples=100)
    score = mape(val_transformed, pred)
    return score  # Optuna will minimize this

# %%
# Defining the output chunk length
# The output chunk length is the number of time steps to predict in the future
forecast_horizon = 24


LOAD = False     # True for hyperparameter tuning
if LOAD:
    print('Hyperparameter tuning:')
    study = optuna.create_study(
        study_name="T22",
        storage="sqlite:///optimization04.db",
        load_if_exists=True,
        direction="minimize")
    study.optimize(objective, n_trials=10, )  # run for 20 trials or 1 hour
    print("Best MAPE:", study.best_value)
    print("Best hyperparameters:", study.best_params)
    best_params = study.best_params
    print(best_params)
else:
    print('loading the study')
    study = optuna.create_study(
        study_name="T22",
        storage="sqlite:///optimization04.db",
        load_if_exists=True,
        direction="minimize")
    best_params = study.best_trial.params
    early_stopper = EarlyStopping(
        monitor="val_loss",  # Using train_loss instead of val_loss might not be a good idea
        min_delta=0.005,
        patience=3,
        verbose=True
    )
    # Define model parameters
    # Define model with single pl_trainer_kwargs
    my_model = TFTModel(

        model_name="TFT",
        input_chunk_length=best_params["input_chunk_length"],
        output_chunk_length=forecast_horizon,
        hidden_size=best_params["hidden_size"],
        lstm_layers=best_params["lstm_layers"],
        dropout=best_params["dropout"],
        add_encoders={
            'cyclic': {'future': ['month', 'day', 'weekday', 'dayofweek', 'hour', 'dayofyear', 'weekofyear'],
                       'past': ['month', 'day', 'weekday', 'dayofweek', 'hour', 'dayofyear', 'weekofyear']},
            'datetime_attribute': {'future': ['hour', 'dayofweek']},
            'position': {'past': ['relative'], 'future': ['relative']},
            'custom': {'past': [encode_year]},
            'transformer': Scaler(),
            'tz': 'UTC'},

        batch_size=256,
        optimizer_kwargs={"lr": best_params["lr"]},
        n_epochs=30,  # now you can train longer
        likelihood=QuantileRegression(quantiles=quantiles),
        random_state=42,
        save_checkpoints=True,
        add_relative_index=True,
        pl_trainer_kwargs={
            "accelerator": accelerator,
            "devices": devices,
            "enable_progress_bar": True,
            "callbacks": [early_stopper],
        },
        force_reset=True
    )
# Out:
# loading the study
# [I 2025-06-04 12:51:35,917] Using an existing study with name 'T22' instead of creating a new one.

# %%
# del my_model

# %%
train_again = False  # Change this to False if you want to retrain

if train_again:
    my_model.fit(
        train_transformed[24:],
        past_covariates=train_past_covs,
        future_covariates=train_future_covs,
        val_series=val_transformed,
        val_past_covariates=val_past_covs,
        val_future_covariates=val_future_covs,
        verbose=True,
    )
    my_model.save("slutlig.pt")
    print("TFT model saved to slutlig.pt")
else:
    print("Skipping training; using existing model if available.")

my_model = None


# Load the model
try:
    # Add all necessary classes to safe globals
    torch.serialization.add_safe_globals([
        MetricCollection,
        QuantileRegression,
        LikelihoodType,
        optim.Adam,
        TFTModel,
        torchmetrics.Metric,
        torchmetrics.MetricCollection,
        getattr
    ])
# Determine the correct device string based on the 'accelerator' variable
    if accelerator == "gpu":
        # If using GPU, use the first device from the 'devices' list
        load_device = torch.device(f"cuda:{devices[0]}")
    else:
        # If using CPU, specify the CPU device
        load_device = torch.device("cpu")
        print('a')
    # Load from the correct path - use the same path as in save()
    my_model = TFTModel.load(
        "slutlig.pt",  # MUST match exactly with my_model.save("my_tft_model")
        map_location=torch.device(
            load_device)
    )
    print("Model loaded successfully")

except Exception as e:
    print(f"Error loading model: {e}")
    raise

print(my_model)
# Out:
# Skipping training; using existing model if available.
# Model loaded successfully
# TFTModel(hidden_size=24, lstm_layers=2, dropout=0.2840171422349407, add_relative_index=True, likelihood=QuantileRegression(quantiles=[0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.99], prior_strength=1.0), model_name=TFT, input_chunk_length=24, output_chunk_length=24, add_encoders={'cyclic': {'future': ['month', 'day', 'weekday', 'dayofweek', 'hour', 'dayofyear', 'weekofyear'], 'past': ['month', 'day', 'weekday', 'dayofweek', 'hour', 'dayofyear', 'weekofyear']}, 'datetime_attribute': {'future': ['hour', 'dayofweek']}, 'position': {'past': ['relative'], 'future': ['relative']}, 'custom': {'past': [<function encode_year at 0x0000021799346AC0>]}, 'transformer': Scaler, 'tz': 'UTC'}, batch_size=256, optimizer_kwargs={'lr': 0.004262542549310246}, n_epochs=30, random_state=42, save_checkpoints=True, pl_trainer_kwargs={'accelerator': 'gpu', 'devices': [0], 'enable_progress_bar': True, 'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x000002179F1D6990>]}, force_reset=True)

# %%
# Select the first 24 time steps from test_past_covs
# Select the last 24 entries from val_past_covs
last_24_covs = val_past_covs[-24:]

# Concatenate the last 24 entries at the start of test_past_covs
test_past_covs = last_24_covs.append(test_past_covs)
print("Start time:", test_past_covs.start_time())

# Select the last 24 entries from val_past_covs
last_24_covs = val_future_covs[-24:]

# Concatenate the last 24 entries at the start of test_past_covs
test_future_covs = last_24_covs.append(test_future_covs)
# Get the first time step of test_transformed

# Append it to val_transformed
next_step = test_transformed[:24]

val_extended = val_transformed.append(next_step)
# Out:
# Start time: 2024-06-30 00:00:00

# %% [markdown]
# # Full Forecast

# %%
forecast_date = pd.Timestamp("2024-07-06 23:00:00")
the_series, discard = test_transformed.split_after(forecast_date)

# %%
forecast = my_model.predict(
    n=len(test) - 7 * 24,
    series=the_series,
    past_covariates=past_covariates_transformed,
    future_covariates=future_covariates_transformed,
    num_samples=100)
# Out:
# `predict()` was called with `n > output_chunk_length`: using auto-regression to forecast the values after `output_chunk_length` points. The model will access `(n - output_chunk_length)` future values of your `past_covariates` (relative to the first predicted time step). To hide this warning, set `show_warnings=False`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
# Inverse transform forecast and train data
forecast_inv = transformer.inverse_transform(forecast)
forecast_inv = forecast_inv
start, end = forecast_inv.start_time(), forecast_inv.end_time()
test_series = test.slice(start, end)
long_forecast = forecast_inv.copy()
long_forecast_actual = test_series.copy()
# Calculate evaluation metrics
tft_mape = mape(test_series, forecast_inv)  # MAPE
tft_rmse = rmse(test_series, forecast_inv)  # RMSE
tft_mae = mae(test_series, forecast_inv)  # MAE

# Print results
print(f"MAPE: {tft_mape:.2f}")
print(f"MAE: {tft_mae:.2f}")
print(f"RMSE: {tft_rmse:.2f}")
# Out:
# MAPE: 4.66
# MAE: 113.10
# RMSE: 168.91

# %%
# plot actual series


plt.figure(figsize=(12, 6))
test_series[: test_series.end_time()].plot(label="actual")
lowest_q, low_q, high_q, highest_q = 0.01, 0.1, 0.9, 0.99
label_q_outer = f"{int(lowest_q * 100)}-{int(highest_q * 100)}th percentiles"
label_q_inner = f"{int(low_q * 100)}-{int(high_q * 100)}th percentiles"
# plot prediction with quantile ranges
forecast_inv.plot(
    low_quantile=lowest_q, high_quantile=highest_q, label=label_q_outer
)
forecast_inv.plot(low_quantile=low_q, high_quantile=high_q,
                  label=label_q_inner)

plt.title(f"MAPE: {mape(test_series, forecast_inv):.2f}%")
plt.legend()

# %% [markdown]
# # Short Forecasts

# %%
# Specify the date for the forecast and number of days to forecast
forecast_dates = [
    pd.Timestamp("2024-07-21 23:00:00"),
    pd.Timestamp("2024-10-13 23:00:00"),
    pd.Timestamp("2024-10-27 23:00:00"),
    pd.Timestamp("2024-12-01 23:00:00"),
    pd.Timestamp("2024-12-22 23:00:00")
]
for i in range(len(forecast_dates)):
    forecast_date = forecast_dates[i]
    number_of_days = 7
    hours = number_of_days * 24
    # split the target series in the same way after forecast date
    the_series, discard = test_transformed.split_after(forecast_date)
    print(the_series.end_time())
    forecast = my_model.predict(
        n=hours,
        series=the_series,
        past_covariates=past_covariates_transformed,
        future_covariates=future_covariates_transformed,
        num_samples=100)
    # Inverse transform forecast and train data
    forecast_inv = transformer.inverse_transform(forecast)
    forecast_inv = forecast_inv
    start, end = forecast_inv.start_time(), forecast_inv.end_time()
    test_series = test.slice(start, end)
    # Inverse transform the quantiles
    forecast_inv_01 = transformer.inverse_transform(forecast.quantile_timeseries(0.01))
    forecast_inv_99 = transformer.inverse_transform(forecast.quantile_timeseries(0.99))
    # Compute the gap (uncertainty interval width) at each time step
    interval_width = forecast_inv_99.values() - forecast_inv_01.values()
    
    # You can now compute statistics over this gap
    mean_gap = np.mean(interval_width)
    std_gap = np.std(interval_width)
    min_gap = np.min(interval_width)
    max_gap = np.max(interval_width)
    
    print(f"Uncertainty gap (mean): {mean_gap:.2f}")
    print(f"Uncertainty gap (std): {std_gap:.2f}")
    print(f"Uncertainty gap (min): {min_gap:.2f}")
    print(f"Uncertainty gap (max): {max_gap:.2f}")



    # Calculate evaluation metrics
    tft_mape = mape(test_series, forecast_inv)  # MAPE
    tft_rmse = rmse(test_series, forecast_inv)  # RMSE
    tft_mse = mse(test_series, forecast_inv)  # MSE
    tft_r2 = r2_score(test_series, forecast_inv)  # R^2
    tft_smape = smape(test_series, forecast_inv)  # SMAPE
    tft_mae = mae(test_series, forecast_inv)  # MAE

    # Print results
    print(f"MAPE: {tft_mape:.2f}")
    print(f"MAE: {tft_mae:.2f}")
    print(f"RMSE: {tft_rmse:.2f}")

    # plot actual series

    plt.figure(figsize=(12, 6))
    test.slice(forecast_inv.start_time(),
               forecast_inv.end_time()).plot(label="actual")
    lowest_q, low_q, high_q, highest_q = 0.01, 0.1, 0.9, 0.99
    label_q_outer = f"{int(lowest_q * 100)}-{int(highest_q * 100)}th percentiles"
    label_q_inner = f"{int(low_q * 100)}-{int(high_q * 100)}th percentiles"
    # plot prediction with quantile ranges
    forecast_inv.plot(
        low_quantile=lowest_q, high_quantile=highest_q, label=label_q_outer
    )
    forecast_inv.plot(low_quantile=low_q,
                      high_quantile=high_q, label=label_q_inner)

    plt.title(f"MAPE: {mape(test_series, forecast_inv):.2f}%")
    plt.legend()
# Out:
# 2024-07-21 23:00:00
# `predict()` was called with `n > output_chunk_length`: using auto-regression to forecast the values after `output_chunk_length` points. The model will access `(n - output_chunk_length)` future values of your `past_covariates` (relative to the first predicted time step). To hide this warning, set `show_warnings=False`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                    | 0/? [00:00<…
# Uncertainty gap (mean): 432.78
# Uncertainty gap (std): 50.92
# Uncertainty gap (min): 309.63
# Uncertainty gap (max): 584.88
# MAPE: 4.23
# MAE: 77.46
# RMSE: 102.38
# 2024-10-13 23:00:00
# `predict()` was called with `n > output_chunk_length`: using auto-regression to forecast the values after `output_chunk_length` points. The model will access `(n - output_chunk_length)` future values of your `past_covariates` (relative to the first predicted time step). To hide this warning, set `show_warnings=False`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                    | 0/? [00:00<…
# Uncertainty gap (mean): 516.41
# Uncertainty gap (std): 67.42
# Uncertainty gap (min): 351.11
# Uncertainty gap (max): 673.16
# MAPE: 4.11
# MAE: 96.68
# RMSE: 119.28
# 2024-10-27 23:00:00
# `predict()` was called with `n > output_chunk_length`: using auto-regression to forecast the values after `output_chunk_length` points. The model will access `(n - output_chunk_length)` future values of your `past_covariates` (relative to the first predicted time step). To hide this warning, set `show_warnings=False`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                    | 0/? [00:00<…
# Uncertainty gap (mean): 513.21
# Uncertainty gap (std): 74.10
# Uncertainty gap (min): 335.16
# Uncertainty gap (max): 687.88
# MAPE: 14.15
# MAE: 411.45
# RMSE: 483.34
# 2024-12-01 23:00:00
# `predict()` was called with `n > output_chunk_length`: using auto-regression to forecast the values after `output_chunk_length` points. The model will access `(n - output_chunk_length)` future values of your `past_covariates` (relative to the first predicted time step). To hide this warning, set `show_warnings=False`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                    | 0/? [00:00<…
# Uncertainty gap (mean): 562.38
# Uncertainty gap (std): 57.42
# Uncertainty gap (min): 400.89
# Uncertainty gap (max): 690.32
# MAPE: 3.88
# MAE: 116.47
# RMSE: 142.18
# 2024-12-22 23:00:00
# `predict()` was called with `n > output_chunk_length`: using auto-regression to forecast the values after `output_chunk_length` points. The model will access `(n - output_chunk_length)` future values of your `past_covariates` (relative to the first predicted time step). To hide this warning, set `show_warnings=False`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |                                                                                    | 0/? [00:00<…
# Uncertainty gap (mean): 485.57
# Uncertainty gap (std): 47.11
# Uncertainty gap (min): 353.77
# Uncertainty gap (max): 610.31
# MAPE: 4.52
# MAE: 116.15
# RMSE: 144.44

# %%
# requires `background` if model was trained on multiple series
explainer = TFTExplainer(my_model)
results = explainer.explain()
# plot the results
explainer.plot_attention(results, plot_type="all")
explainer.plot_variable_selection(results)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
